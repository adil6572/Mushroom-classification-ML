# %% [markdown]
# # Mushroom Classification
#
# ## Attribute Information:
#
# class: edible=e, poisonous=p
#
# cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
#
# cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
#
# cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y
#
# bruises: bruises=t,no=f
#
# odor: almond=a,anise=l,creosote=c,fishy=y,foul=f,musty=m,none=n,pungent=p,spicy=s
#
# gill-attachment: attached=a,descending=d,free=f,notched=n
#
# gill-spacing: close=c,crowded=w,distant=d
#
# gill-size: broad=b,narrow=n
#
# gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e,white=w,yellow=y
#
# stalk-shape: enlarging=e,tapering=t
#
# stalk-root: bulbous=b,club=c,cup=u,equal=e,rhizomorphs=z,rooted=r,missing=?
#
# stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
#
# stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
#
# stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
#
# stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
#
# veil-type: partial=p,universal=u
#
# veil-color: brown=n,orange=o,white=w,yellow=y
#
# ring-number: none=n,one=o,two=t
#
# ring-type: cobwebby=c,evanescent=e,flaring=f,large=l,none=n,pendant=p,sheathing=s,zone=z
#
# spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r,orange=o,purple=u,white=w,yellow=y
#
# population: abundant=a,clustered=c,numerous=n,scattered=s,several=v,solitary=y
#
# habitat: grasses=g,leaves=l,meadows=m,paths=p,urban=u,waste=w,woods=d

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("mushrooms.csv")

# %%
dataset
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# ### 2. preprocessing

# %%
# checking null values
dataset.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
dataset.drop_duplicates()
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %% [markdown]
# #### There is no null and duplicate values
# #### All Features are categorical

# %% [markdown]
# ### 3. Visualization

# %%
columns_list = dataset.columns
num_rows = (len(columns_list) + 2) // 3

fig, axes = plt.subplots(num_rows, 3, figsize=(15, num_rows*5))

axes = axes.flatten()

# Loop through each column and plot the countplot on the corresponding axis
for i, column in enumerate(columns_list):
    sns.countplot(x=column, data=dataset, ax=axes[i])
    axes[i].set_title(column)

# Show the plots
plt.show()

# %% [markdown]
# #### veil-type features has only one value , we can drop it

# %%
dataset.drop(["veil-type"],axis=1,inplace=True)
# Out:
# C:\Users\adils\AppData\Local\Temp\ipykernel_27656\2911790877.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=dataset.corr())
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 dataset.drop(["veil-type"],axis=1,inplace=True)
# ----> 2 sns.heatmap(data=dataset.corr())
#
# File C:\ProgramData\anaconda3\lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
# ...

# %% [markdown]
# #### All featutres are categorical encoding is required. Label Encoder is best way to do it in this case

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split

# %%
mappings=list()
encoder=LabelEncoder()
for col in range(len(dataset.columns)):
    dataset[dataset.columns[col]] = encoder.fit_transform(dataset[dataset.columns[col]])
    mappings_dict = {index: label for index, label in enumerate(encoder.classes_)}
    mappings.append(mappings_dict)

# %%
mappings
# Out:
# [{0: 'e', 1: 'p'},
#  {0: 'b', 1: 'c', 2: 'f', 3: 'k', 4: 's', 5: 'x'},
#  {0: 'f', 1: 'g', 2: 's', 3: 'y'},
#  {0: 'b',
#   1: 'c',
#   2: 'e',
#   3: 'g',
#   4: 'n',
#   5: 'p',
#   6: 'r',
#   7: 'u',
#   8: 'w',
#   9: 'y'},
#  {0: 'f', 1: 't'},
#  {0: 'a', 1: 'c', 2: 'f', 3: 'l', 4: 'm', 5: 'n', 6: 'p', 7: 's', 8: 'y'},
#  {0: 'a', 1: 'f'},
#  {0: 'c', 1: 'w'},
#  {0: 'b', 1: 'n'},
#  {0: 'b',
#   1: 'e',
#   2: 'g',
#   3: 'h',
#   4: 'k',
#   5: 'n',
#   6: 'o',
#   7: 'p',
#   8: 'r',
#   9: 'u',
#   10: 'w',
#   11: 'y'},
#  {0: 'e', 1: 't'},
#  {0: '?', 1: 'b', 2: 'c', 3: 'e', 4: 'r'},
#  {0: 'f', 1: 'k', 2: 's', 3: 'y'},
#  {0: 'f', 1: 'k', 2: 's', 3: 'y'},
#  {0: 'b', 1: 'c', 2: 'e', 3: 'g', 4: 'n', 5: 'o', 6: 'p', 7: 'w', 8: 'y'},
#  {0: 'b', 1: 'c', 2: 'e', 3: 'g', 4: 'n', 5: 'o', 6: 'p', 7: 'w', 8: 'y'},
#  {0: 'n', 1: 'o', 2: 'w', 3: 'y'},
#  {0: 'n', 1: 'o', 2: 't'},
#  {0: 'e', 1: 'f', 2: 'l', 3: 'n', 4: 'p'},
# ...

# %%
X=dataset.drop("class",axis=1)
y=dataset["class"]

# %%
scaler=StandardScaler()
X=pd.DataFrame(scaler.fit_transform(X),columns=X.columns)

# %% [markdown]
# ### Train-test Split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (6499, 21)
# (1625, 21)

# %% [markdown]
# ### Model Fitting

# %%
from sklearn.linear_model import  LogisticRegression
from sklearn.tree import  DecisionTreeClassifier
from sklearn.svm import  SVC
from sklearn.ensemble import RandomForestClassifier

# %%
models=[
    LogisticRegression(),
    DecisionTreeClassifier(),
    SVC(),
    RandomForestClassifier()
]

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,ConfusionMatrixDisplay

# %%
for index,model in enumerate(models):
    model.fit(X_train,y_train)
    pred=model.predict(X_test)
    print(f"{models[index]} Acucracy score :{accuracy_score(y_test,pred)}")
# Out:
# LogisticRegression() Acucracy score :0.9587692307692308
# DecisionTreeClassifier() Acucracy score :1.0
# SVC() Acucracy score :1.0
# RandomForestClassifier() Acucracy score :1.0

# %% [markdown]
# #### for classfication problem f1-score and confusion matrix is better matrics for perofmance of model

# %%
for index,model in enumerate(models):
    print("===============")
    print(f"{model}")
    print("===============")
    pred=model.predict(X_test)
    print(f"Acucracy score :{accuracy_score(y_test,pred)}")
    cm = confusion_matrix(y_test, pred, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot(cmap='Blues')
    plt.show()
    print(classification_report(y_test,pred))
# Out:
# ...
# LogisticRegression()
# ...
# Acucracy score :0.9587692307692308
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       816
#            1       0.96      0.95      0.96       809
#
#     accuracy                           0.96      1625
#    macro avg       0.96      0.96      0.96      1625
# weighted avg       0.96      0.96      0.96      1625
#
# ...
# DecisionTreeClassifier()
# ...
# Acucracy score :1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       816
#            1       1.00      1.00      1.00       809
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625
#
# ...
# SVC()
# ...
# Acucracy score :1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       816
#            1       1.00      1.00      1.00       809
#
# ...
